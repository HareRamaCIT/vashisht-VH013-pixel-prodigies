# %%
import datetime
import hashlib
class Block:
    blockNo = 0
    data = None
    next  = None
    hash = None
    nonce = 0
    previous_hash = 0x0
    timestamp = datetime.datetime.now()
    def __init__(self, data):
        self.data = data
    def hash(self):
        h = hashlib.sha256()
        h.update(
        str(self.nonce).encode('utf-8') +
        str(self.data).encode('utf-8') +
        str(self.previous_hash).encode('utf-8') +
        str(self.timestamp).encode('utf-8') +
        str(self.blockNo).encode('utf-8')
        )
        return h.hexdigest()
    def __str__(self):
        return "Block Hash: " + str(self.hash()) + "\nBlockNo: " + str(self.blockNo) + "\nBlock Data: " + str(self.data) + "\nHashes: " + str(self.previous_hash) + "\nTimestamp:" + str(self.timestamp) + "\nNonce: " + str(self.nonce)
class Blockchain:
    diff = 20
    maxNonce = 2**32
    traget = 2**(256-diff)
    block = Block("Genesis")
    dummy = head = block
    def add(self, block):
        block.previous_hash = self.block.hash()
        block.blockNo = self.block.blockNo + 1
        self.block.next = block
        self.block = self.block.next
    def mine(self, block):
        for n in range(self.maxNonce):
            if int(block.hash(), 16) <= self.traget:
                self.add(block)
                print(block)
                break
            else:
                block.nonce += 1
blockchain = Blockchain()
for n in range(10):
    blockchain.mine(Block("Block " + str(n + 1)))
while blockchain.head != None:
    print(blockchain.head)
    blockchain.head = blockchain.head.next
# Out:
# Block Hash: 808e924fc83aee2ac7e0a7bbe1136fcc59836e8e763ecd03bfc1d2a8da81aec7
# BlockNo: 1
# Block Data: Block 1
# Hashes: 5f91928e66e0a9c239250be0a9c111d551fcfd50a31a4195e5c048cd64fee0b4
# Timestamp:2024-03-17 11:11:40.656445
# Nonce: 686104
# Block Hash: ebaa581eaaee4e3509bd6fbb667ac748c3f5486250f85eb7389dd53ffc002ad4
# BlockNo: 2
# Block Data: Block 2
# Hashes: 808e924fc83aee2ac7e0a7bbe1136fcc59836e8e763ecd03bfc1d2a8da81aec7
# Timestamp:2024-03-17 11:11:40.656445
# Nonce: 1469108
# Block Hash: 011523b331ab924214e163660a0bd7ea99f3b3e72e31e65edf30e0a2f643d36a
# BlockNo: 3
# Block Data: Block 3
# Hashes: ebaa581eaaee4e3509bd6fbb667ac748c3f5486250f85eb7389dd53ffc002ad4
# Timestamp:2024-03-17 11:11:40.656445
# Nonce: 273446
# Block Hash: 1578de6c0274707aa3ed733236b500e65922a2afbf39bbafa88e17c2472a4de2
# BlockNo: 4
# Block Data: Block 4
# Hashes: 011523b331ab924214e163660a0bd7ea99f3b3e72e31e65edf30e0a2f643d36a
# Timestamp:2024-03-17 11:11:40.656445
# Nonce: 217573
# Block Hash: 469f63bf860acb30c0e7b7520dd78d1e663a03093aad5052e9fb382ce588702e
# BlockNo: 5
# Block Data: Block 5
# Hashes: 1578de6c0274707aa3ed733236b500e65922a2afbf39bbafa88e17c2472a4de2
# Timestamp:2024-03-17 11:11:40.656445
# Nonce: 735195
# Block Hash: 78fa56c3ea8c53afe2c7ce27293a00e3ce383e63fb152101aa8cb1d7dc9f2bc3
# BlockNo: 6
# Block Data: Block 6
# Hashes: 469f63bf860acb30c0e7b7520dd78d1e663a03093aad5052e9fb382ce588702e
# Timestamp:2024-03-17 11:11:40.656445
# Nonce: 71853
# Block Hash: 803a056fa2cb8c669c030aaed363779e3cd5d1dceb70e721876f4539f3237389
# BlockNo: 7
# Block Data: Block 7
# Hashes: 78fa56c3ea8c53afe2c7ce27293a00e3ce383e63fb152101aa8cb1d7dc9f2bc3
# Timestamp:2024-03-17 11:11:40.656445
# Nonce: 493849
# Block Hash: 90e78811f98b5f57bf6537bffaae2bbed3afdb21102211d18e1162ba512e6aab
# BlockNo: 8
# Block Data: Block 8
# Hashes: 803a056fa2cb8c669c030aaed363779e3cd5d1dceb70e721876f4539f3237389
# Timestamp:2024-03-17 11:11:40.656445
# Nonce: